# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
data = np.genfromtxt("glass.data.csv", delimiter=',')


print(data.shape,data[0:5,:])
# Out:
# (214, 11) [[1.00000e+00 1.52101e+00 1.36400e+01 4.49000e+00 1.10000e+00 7.17800e+01
#   6.00000e-02 8.75000e+00 0.00000e+00 0.00000e+00 1.00000e+00]
#  [2.00000e+00 1.51761e+00 1.38900e+01 3.60000e+00 1.36000e+00 7.27300e+01
#   4.80000e-01 7.83000e+00 0.00000e+00 0.00000e+00 1.00000e+00]
#  [3.00000e+00 1.51618e+00 1.35300e+01 3.55000e+00 1.54000e+00 7.29900e+01
#   3.90000e-01 7.78000e+00 0.00000e+00 0.00000e+00 1.00000e+00]
#  [4.00000e+00 1.51766e+00 1.32100e+01 3.69000e+00 1.29000e+00 7.26100e+01
#   5.70000e-01 8.22000e+00 0.00000e+00 0.00000e+00 1.00000e+00]
#  [5.00000e+00 1.51742e+00 1.32700e+01 3.62000e+00 1.24000e+00 7.30800e+01
#   5.50000e-01 8.07000e+00 0.00000e+00 0.00000e+00 1.00000e+00]]

# %%
X = data[:, 1:10]
y = data[:, 10]
print(X.shape, y.shape)
# Out:
# (214, 9) (214,)

# %%
y = y.reshape(-1,1)
print(y.shape)
# Out:
# (214, 1)

# %%
print(X[0:5,:])
# Out:
# [[1.52101e+00 1.36400e+01 4.49000e+00 1.10000e+00 7.17800e+01 6.00000e-02
#   8.75000e+00 0.00000e+00 0.00000e+00]
#  [1.51761e+00 1.38900e+01 3.60000e+00 1.36000e+00 7.27300e+01 4.80000e-01
#   7.83000e+00 0.00000e+00 0.00000e+00]
#  [1.51618e+00 1.35300e+01 3.55000e+00 1.54000e+00 7.29900e+01 3.90000e-01
#   7.78000e+00 0.00000e+00 0.00000e+00]
#  [1.51766e+00 1.32100e+01 3.69000e+00 1.29000e+00 7.26100e+01 5.70000e-01
#   8.22000e+00 0.00000e+00 0.00000e+00]
#  [1.51742e+00 1.32700e+01 3.62000e+00 1.24000e+00 7.30800e+01 5.50000e-01
#   8.07000e+00 0.00000e+00 0.00000e+00]]

# %%
print(y[0:5,:])
# Out:
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]]

# %%
np.unique(y)
# Out:
# array([1., 2., 3., 5., 6., 7.])

# %%
mean_vals = np.mean(X, axis=0)
std_dev = np.std(X, axis=0)
min_vals = np.min(X, axis=0)
max_vals = np.max(X, axis=0)
print('Mean Values:', np.round(mean_vals, 4))
print('Standard Deviation:', np.round(std_dev,4))
print('Min Values:', np.round(min_vals, 4))
print('Max Values:', np.round(max_vals,4))
# Out:
# Mean Values: [1.51840e+00 1.34079e+01 2.68450e+00 1.44490e+00 7.26509e+01 4.97100e-01
#  8.95700e+00 1.75000e-01 5.70000e-02]
# Standard Deviation: [0.003  0.8147 1.439  0.4981 0.7727 0.6507 1.4198 0.4961 0.0972]
# Min Values: [ 1.5112 10.73    0.      0.29   69.81    0.      5.43    0.      0.    ]
# Max Values: [ 1.5339 17.38    4.49    3.5    75.41    6.21   16.19    3.15    0.51  ]

# %%
fig, axs = plt.subplots(3, 3, figsize=(15, 15))
# Plotting the histogram for each feature
counter = 0
for i in range(3):
    for j in range(3):
        counter = counter + 1
        if counter > X.shape[1]: break
        axs[i, j].hist(X[:, counter-1], bins=20, color='blue', alpha=0.7)
        axs[i, j].set_title(f'Feature {counter}')
plt.show()

# %%
fig, axs = plt.subplots(1,1,figsize=(15, 15))
axs.hist(y, bins=20, color='red', alpha=0.7)
axs.set_title('Labels')
plt.show()

# %%
cor_matrix = np.corrcoef(X, rowvar=False)
# Plot the correlation matrix
plt.figure(figsize=(12, 12))
cax = plt.matshow(cor_matrix, cmap='coolwarm')
plt.colorbar(cax)
plt.title('Correlation Matrix', pad=20)
plt.show()

# %%
encoder = OneHotEncoder(sparse=False)
y_enc = encoder.fit_transform(y.reshape(-1, 1))
print(y_enc.shape)
# Out:
# (214, 6)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_enc, test_size=0.2,
random_state=42)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
len(y_enc[0])
# Out:
# 6

# %%
# Build the neural network model
model = Sequential()
# Add layers to the model
model.add(Dense(16, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(len((y_enc[0])), activation='softmax'))
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                160
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 4)                 36
#
#  dense_3 (Dense)             (None, 6)                 30
#
# =================================================================
# Total params: 362
# Trainable params: 362
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train the model
history = model.fit(X_train_scaled, y_train, epochs=100, batch_size=32,
validation_split=0.2)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 50ms/step - loss: 1.7903 - accuracy: 0.3015 - val_loss: 1.7861 - val_accuracy: 0.3143
# Epoch 2/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7854 - accuracy: 0.3824 - val_loss: 1.7830 - val_accuracy: 0.3429
# Epoch 3/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7809 - accuracy: 0.3676 - val_loss: 1.7798 - val_accuracy: 0.3429
# Epoch 4/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.7764 - accuracy: 0.3676 - val_loss: 1.7761 - val_accuracy: 0.2857
# Epoch 5/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7711 - accuracy: 0.3897 - val_loss: 1.7718 - val_accuracy: 0.2857
# Epoch 6/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.7657 - accuracy: 0.3897 - val_loss: 1.7675 - val_accuracy: 0.2857
# Epoch 7/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7600 - accuracy: 0.3897 - val_loss: 1.7619 - val_accuracy: 0.2857
# Epoch 8/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7535 - accuracy: 0.4044 - val_loss: 1.7559 - val_accuracy: 0.2857
# Epoch 9/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7464 - accuracy: 0.3897 - val_loss: 1.7494 - val_accuracy: 0.2857
# Epoch 10/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7396 - accuracy: 0.3897 - val_loss: 1.7422 - val_accuracy: 0.2857
# Epoch 11/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7311 - accuracy: 0.3897 - val_loss: 1.7345 - val_accuracy: 0.2857
# Epoch 12/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7217 - accuracy: 0.3897 - val_loss: 1.7258 - val_accuracy: 0.2857
# Epoch 13/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7115 - accuracy: 0.3824 - val_loss: 1.7164 - val_accuracy: 0.2857
# Epoch 14/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6999 - accuracy: 0.3750 - val_loss: 1.7070 - val_accuracy: 0.2857
# Epoch 15/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6864 - accuracy: 0.3750 - val_loss: 1.6970 - val_accuracy: 0.2571
# Epoch 16/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6718 - accuracy: 0.3676 - val_loss: 1.6855 - val_accuracy: 0.2571
# Epoch 17/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6556 - accuracy: 0.3676 - val_loss: 1.6727 - val_accuracy: 0.2571
# Epoch 18/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6390 - accuracy: 0.3676 - val_loss: 1.6596 - val_accuracy: 0.2571
# Epoch 19/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6206 - accuracy: 0.3676 - val_loss: 1.6468 - val_accuracy: 0.2571
# Epoch 20/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6019 - accuracy: 0.3676 - val_loss: 1.6343 - val_accuracy: 0.2571
# Epoch 21/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.
100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0271 - accuracy: 0.4926 - val_loss: 1.3923 - val_accuracy: 0.4000
# Epoch 82/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.0230 - accuracy: 0.5000 - val_loss: 1.3877 - val_accuracy: 0.4000
# Epoch 83/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0198 - accuracy: 0.5000 - val_loss: 1.3861 - val_accuracy: 0.4000
# Epoch 84/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0167 - accuracy: 0.5000 - val_loss: 1.3858 - val_accuracy: 0.4000
# Epoch 85/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0136 - accuracy: 0.5000 - val_loss: 1.3892 - val_accuracy: 0.4000
# Epoch 86/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.0104 - accuracy: 0.4926 - val_loss: 1.3916 - val_accuracy: 0.4000
# Epoch 87/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0076 - accuracy: 0.4926 - val_loss: 1.3963 - val_accuracy: 0.4000
# Epoch 88/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0051 - accuracy: 0.5000 - val_loss: 1.4013 - val_accuracy: 0.4000
# Epoch 89/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0034 - accuracy: 0.5074 - val_loss: 1.4025 - val_accuracy: 0.4000
# Epoch 90/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.0007 - accuracy: 0.5074 - val_loss: 1.4007 - val_accuracy: 0.4000
# Epoch 91/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.9985 - accuracy: 0.5000 - val_loss: 1.3990 - val_accuracy: 0.4000
# Epoch 92/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.9971 - accuracy: 0.5000 - val_loss: 1.3996 - val_accuracy: 0.4000
# Epoch 93/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.9951 - accuracy: 0.5000 - val_loss: 1.4030 - val_accuracy: 0.4000
# Epoch 94/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.9933 - accuracy: 0.5074 - val_loss: 1.4058 - val_accuracy: 0.4000
# Epoch 95/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.9914 - accuracy: 0.5074 - val_loss: 1.4117 - val_accuracy: 0.4000
# Epoch 96/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.9898 - accuracy: 0.5147 - val_loss: 1.4139 - val_accuracy: 0.4000
# Epoch 97/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.9883 - accuracy: 0.5221 - val_loss: 1.4159 - val_accuracy: 0.4000
# Epoch 98/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.9867 - accuracy: 0.5221 - val_loss: 1.4172 - val_accuracy: 0.4000
# Epoch 99/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.9847 - accuracy: 0.5221 - val_loss: 1.4194 - val_accuracy: 0.4000
# Epoch 100/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.9832 - accuracy: 0.5221 - val_loss: 1.4210 - val_accuracy: 0.4000

# %%
# Visualize Model Training History
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
predictions = model.predict (X_test)
print(predictions.shape, y_test.shape)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 39.6115 - accuracy: 0.2558
# Test Loss: 39.61145782470703
# Test Accuracy: 0.25581395626068115
# 2/2 [==============================] - 0s 2ms/step
# (43, 6) (43, 6)

# %%
from sklearn.metrics import confusion_matrix, classification_report
cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(predictions, axis=1))
print(cm)
cr = classification_report(np.argmax(y_test, axis=1), np.argmax(predictions,
axis=1))
print(cr)
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True,
show_layer_names=True)
# Out:
# [[11  0  0  0  0  0]
#  [14  0  0  0  0  0]
#  [ 3  0  0  0  0  0]
#  [ 4  0  0  0  0  0]
#  [ 3  0  0  0  0  0]
#  [ 8  0  0  0  0  0]]
#               precision    recall  f1-score   support
#
#            0       0.26      1.00      0.41        11
#            1       0.00      0.00      0.00        14
#            2       0.00      0.00      0.00         3
#            3       0.00      0.00      0.00         4
#            4       0.00      0.00      0.00         3
#            5       0.00      0.00      0.00         8
#
#     accuracy                           0.26        43
#    macro avg       0.04      0.17      0.07        43
# weighted avg       0.07      0.26      0.10        43
#
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# C:\Users\schmi\anaconda3\envs\TF23\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\schmi\anaconda3\envs\TF23\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\schmi\anaconda3\envs\TF23\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
